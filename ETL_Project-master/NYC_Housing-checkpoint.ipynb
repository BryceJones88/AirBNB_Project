# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
airbnb_data = ('Resources/nyc-rolling-sales.csv')
airbnb_df = pd.read_csv(airbnb_data)
AB_df = pd.DataFrame(airbnb_df)
AB_df
# Out:
#       Unnamed: 0  BOROUGH       NEIGHBORHOOD  \
# 0           7045        1   MANHATTAN VALLEY
# 1           7046        1   MANHATTAN VALLEY
# 2           7047        1   MANHATTAN VALLEY
# 3           7048        1   MANHATTAN VALLEY
# 4           7049        1   MANHATTAN VALLEY
# ...          ...      ...                ...
# 1340        6924        5  STAPLETON-CLIFTON
# 1341        6926        5  STAPLETON-CLIFTON
# 1342        6927        5  STAPLETON-CLIFTON
# 1343        6928        5  STAPLETON-CLIFTON
# 1344        6929        5  STAPLETON-CLIFTON
#
#                           BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0     04 TAX CLASS 1 CONDOS                                         1C   1847
# 1     04 TAX CLASS 1 CONDOS                                         1C   1847
# 2     07 RENTALS - WALKUP APARTMENTS                                 2   1836
# 3     07 RENTALS - WALKUP APARTMENTS                                 2   1837
# ...

# %%
NY_AB_reorganized = AB_df[["NEIGHBORHOOD","SALE PRICE"]]
# NY_AB_reorganized["SALE PRICE"] = NY_AB_reorganized["SALE PRICE"].replace(' -  ', '')
# NY_AB_reorganized["SALE PRICE"] = NY_AB_reorganized["SALE PRICE"].dropna()

# %%
NY_sales = NY_AB_reorganized["SALE PRICE"].mean()
NY_sales
# Out:
# 1310739.926394052

# %%
is_inf = NY_AB_reorganized["SALE PRICE"] == np.inf
NY_AB_reorganized.loc[~is_inf, "SALE PRICE"].mean()
# Out:
# 1310739.926394052

# %%
np.mean(NY_AB_reorganized["SALE PRICE"][np.isfinite(NY_AB_reorganized["SALE PRICE"])])
# Out:
# 1310739.926394052

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['NEIGHBORHOOD', 'SALE PRICE']).cumsum()

df3['NEIGHBORHOOD'] = pd.Series(list(range(len(NY_AB_reorganized))))

df3.plot(x='NEIGHBORHOOD', y='SALE PRICE')
