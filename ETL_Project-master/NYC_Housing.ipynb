# %%
import pandas as pd

# %%
airbnb_data_url = ('Resources/nyc-rolling-sales.csv')
airbnb_df = pd.read_csv(airbnb_data, encoding="UTF-8")
AB_df = pd.DataFrame(airbnb_df)
AB_df.head()
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# ...

# %%
NY_AB_reorganized = AB_df[["NEIGHBORHOOD","SALE PRICE"]]
NY_AB_reorganized
# Out:
#         NEIGHBORHOOD SALE PRICE
# 0      ALPHABET CITY    6625000
# 1      ALPHABET CITY        -
# 2      ALPHABET CITY        -
# 3      ALPHABET CITY    3936272
# 4      ALPHABET CITY    8000000
# ...              ...        ...
# 84543        WOODROW     450000
# 84544        WOODROW     550000
# 84545        WOODROW     460000
# 84546        WOODROW   11693337
# 84547        WOODROW      69300
#
# [84548 rows x 2 columns]

# %%
grouped_NYC_df = NY_AB_reorganized.groupby(['NEIGHBORHOOD', 'SALE PRICE'])
grouped_NYC_df.count()
# Out:
# Empty DataFrame
# Columns: []
# ...
