# %%
import pandas as pd

# %%
airbnb_data = "Resources/AB_NYC_2019.csv"
airbnb_df = pd.read_csv(airbnb_data, encoding="UTF-8")
# Out:
# C:\Users\Bryce Jones\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (0,2,6,7,9,10,11,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
AB_df = pd.DataFrame(airbnb_df)
AB_df.head()
# Out:
#          id                                               name    host_id  \
# 0       ﻿id                                               name    host_id
# 1   8423666         "Bloom of Floral Park" 1 BR Basement Suite   44361695
# 2   8423666         "Bloom of Floral Park" 1 BR Basement Suite   44361695
# 3  35638944  â˜€Bright & sunny townhouse | Perfect for fami...  154268909
# 4  35638944  â˜€Bright & sunny townhouse | Perfect for fami...  154268909
#
#    host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0  host_name  neighbourhood_group  neighbourhood  latitude  longitude
# 1   Mordeana               Queens      Bellerose  40.73351  -73.71299
# 2   Mordeana               Queens      Bellerose  40.73351  -73.71299
# 3      Malik               Queens      Bellerose  40.74006   -73.7169
# 4      Malik               Queens      Bellerose  40.74006   -73.7169
#
#          room_type  price  minimum_nights  number_of_reviews  last_review  \
# 0        room_type  price  minimum_nights  number_of_reviews  last_review
# 1     Private room     65               2                 39    5/29/2019
# 2     Private room     65               2                 39    5/29/2019
# 3  Entire home/apt    240               2                  0          NaN
# 4  Entire home/apt    240               2                  0          NaN
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0  reviews_per_month  calculated_host_listings_count  availability_365
# 1               0.85                               1               222
# 2               0.85                               1               222
# 3                NaN                               2               159
# 4                NaN                               2               159

# %%
NY_AB_reorganized = AB_df[["neighbourhood_group", "room_type", "price"]]
NY_AB_reorganized.head()
# Out:
#    neighbourhood_group        room_type  price
# 0  neighbourhood_group        room_type  price
# 1               Queens     Private room     65
# 2               Queens     Private room     65
# 3               Queens  Entire home/apt    240
# 4               Queens  Entire home/apt    240

# %%
NY_renamed = NY_AB_reorganized.rename(columns={"neighbourhood_group": "Neighborhood", "room_type": "Room type"})
NY_renamed.head()
# Out:
#           Neighborhood        Room type  price
# 0  neighbourhood_group        room_type  price
# 1               Queens     Private room     65
# 2               Queens     Private room     65
# 3               Queens  Entire home/apt    240
# 4               Queens  Entire home/apt    240

# %%
#groupby neighborhood, display neighborhood by room type, neighborhood by price

grouped_NYC_df = NY_renamed.groupby(['Neighborhood', 'Room type'])
grouped_NYC_df.count().head(15)
# Out:
#                                price
# Neighborhood  Room type
# Bronx         Entire home/apt    758
#               Private room      1304
#               Shared room        120
# Brooklyn      Entire home/apt  19118
#               Private room     20264
#               Shared room        826
# Manhattan     Entire home/apt  26398
#               Private room     15964
#               Shared room        960
# Queens        Entire home/apt   4192
#               Private room      6744
#               Shared room        396
# Staten Island Entire home/apt    352
#               Private room       376
#               Shared room         18

# %%
avg_price_NYC_df = pd.DataFrame(NY_renamed.groupby(['Neighborhood', 'Room type']).mean()['price'])
avg_price_NYC_df
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-7-f4e3e733d6af> in <module>
# ----> 1 avg_price_NYC_df = pd.DataFrame(NY_renamed.groupby(['Neighborhood', 'Room type']).mean()['price'])
#       2 avg_price_NYC_df
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1203         try:
#    1204             return self._cython_agg_general(
# -> 1205                 "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1206             )
#    1207         except GroupByError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     126     def _cython_agg_general(self, how, alt=None, numeric_only=True, min_count=-1):
#     127         new_items, new_blocks = self._cython_agg_blocks(
# --> 128             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#     129         )
#     130         return self._wrap_agged_blocks(new_items, new_blocks)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#     186
#     187         if len(new_blocks) == 0:
# --> 188             raise DataError("No numeric types to aggregate")
#     189
#     190         # reset the locs in the blocks to correspond to our
#
# DataError: No numeric types to aggregate
